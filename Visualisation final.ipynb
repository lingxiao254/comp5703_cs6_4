# %%
# Use GPU
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 134923 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.13-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.13-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.13-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse -o nonempty drive

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.getcwd()
os.chdir('/content/drive/My Drive/')
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %%
#import library
import pandas as pd
import numpy as np
from glob import glob
import fnmatch
import cv2
import time
import os 
start_time = time.time()

# %%
from os import listdir
from cv2 import imread

import matplotlib.pyplot as plt



import matplotlib as mpl

# %%
base_path = "/content/drive/My Drive/IDC/"
folder = listdir(base_path)
len(folder)
# Out:
# 223

# %%
def get_cancer_dataframe(patient_id, cancer_id):
    path = base_path + patient_id + "/" + cancer_id
    files = listdir(path)
    dataframe = pd.DataFrame(files, columns=["filename"])
    path_names = path + "/" + dataframe.filename.values
    dataframe = dataframe.filename.str.rsplit("_", n=4, expand=True)
    dataframe.loc[:, "target"] = np.int(cancer_id)
    dataframe.loc[:, "path"] = path_names
    dataframe = dataframe.drop([0, 1, 4], axis=1)
    dataframe = dataframe.rename({2: "x", 3: "y"}, axis=1)
    dataframe.loc[:, "x"] = dataframe.loc[:,"x"].str.replace("x", "", case=False).astype(np.int)
    dataframe.loc[:, "y"] = dataframe.loc[:,"y"].str.replace("y", "", case=False).astype(np.int)
    return dataframe

def get_patient_dataframe(patient_id):
    df_0 = get_cancer_dataframe(patient_id, "0")
    df_1 = get_cancer_dataframe(patient_id, "1")
    patient_df = df_0.append(df_1)
    return patient_df

# %% [markdown]
# # Patient 10253 visualisation

# %%
base_path = "/content/drive/My Drive/IDC_regular_ps50_idx5/"
folder = listdir(base_path)
len(folder)

path = base_path + "10253" + "/" + "0"
files = listdir(path)
dataframe = pd.DataFrame(files, columns=["filename"])
path_names = path + "/" + dataframe.filename.values
dataframe = dataframe.filename.str.rsplit("_", n=4, expand=True)
len(files)
# Out:
# 479

# %%
def visualise_breast_tissue(patient_id):
    pass

# %%
example = "10253"

example_df = get_patient_dataframe(example)
max_point = [example_df.y.max()-1, example_df.x.max()-1]
grid = 255*np.ones(shape = (max_point[0] + 50, max_point[1] + 50, 3)).astype(np.uint8)
mask = 255*np.ones(shape = (max_point[0] + 50, max_point[1] + 50, 3)).astype(np.uint8)

broken_patches = []
for n in range(len(example_df)):
    try:
        image = imread(example_df.path.values[n])

        x_start = example_df.x.values[n] - 1
        y_start = example_df.y.values[n] - 1
        x_end = x_start + 50
        y_end = y_start + 50

        grid[y_start:y_end, x_start:x_end] = image
     
        #mask[y_start:y_end, x_start:x_end] = np.ones(shape=(50,50,3))
    except ValueError:
        broken_patches.append(example_df.path.values[n])

# %% [markdown]
# Save image coordinates

# %%
example_df.head()

example_df.to_pickle("patient10253_coordinate.pkl")

# %%
from pandas import api 
from pandas.api import types 
from pandas.api.types import is_numeric_dtype

# %%
is_numeric_dtype(example_df['target'])
data = example_df[['x','y', 'target']] 
data.head()
# Out:
#       x     y  target
# 0  1001  1001       0
# 1  1001  1151       0
# 2  1001  1551       0
# 3  1001  1201       0
# 4  1001  1301       0

# %%
import numpy as np

import matplotlib.pyplot as plt
from  matplotlib.pyplot import scatter

x=example_df['x']
y=example_df['y']
data = example_df[['x','y', 'target']]
colors = ("grey", "red")
groups = ("0","1")

# Create plot
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x,y, alpha=0.8, edgecolor='none', s=30, c=data.target )
#for data, color, group in zip(data, colors, groups):
# x,y=data
#  ax.scatter(x, y, alpha=0.8, c=colors, edgecolor='none', s=30, label=group)

plt.title('patient 10253')
plt.legend(labels=groups)
plt.legend(loc=2)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(20,20))
plt.imshow(grid, cmap="Blues", vmin=150, alpha=0.8)
plt.grid(False)

# %% [markdown]
# Create lables for prediction

# %%
#create labels
ImagePatch = glob('/content/drive/My Drive/IDC/10253/**/*.png', recursive=True) #replace 'D:/comp5703/input with own input patch
Pattern0 = '*class0.png'
Pattern1 = '*class1.png'
Class0 = fnmatch.filter(ImagePatch, Pattern0)
Class1 = fnmatch.filter(ImagePatch, Pattern1)

def image_proc(lindex,uindex):
    x = []
    y = []

    for img in ImagePatch[lindex:uindex]:
        full_size_image = cv2.imread(img)
        x.append(cv2.resize(full_size_image, (50,50), interpolation=cv2.INTER_CUBIC))
        if img in Class0:
            y.append(0)
        elif img in Class1:
            y.append(1)
        else:
            return
    return x,y

X,Y = image_proc(0,2000)

# %%
#data description
original_data = pd.DataFrame()
original_data["image"]=X
original_data["label"]=Y
X1=original_data["image"]
Y1=original_data["label"]

def describe_data(x,y):
    print('Total number: {}'.format(len(x)))
    print('Number of IDC(-): {}'.format(np.sum(y==0)))
    print('Number of IDC(+): {}'.format(np.sum(y==1)))
    print('Percentage of IDC(+) : {:.2f}%'.format(100*np.mean(y)))
describe_data(X1, Y1)
# Out:
# Total number: 0
# Number of IDC(-): 0
# Number of IDC(+): 0
# Percentage of IDC(+) : nan%

# %%
np.save("X_patient10253.npy",X)

# %% [markdown]
# # Patient 12242 visualisation

# %%
base_path = "/content/drive/My Drive/IDC/"
folder = listdir(base_path)
len(folder)

path = base_path + "12242" + "/" + "0"
files = listdir(path)
dataframe = pd.DataFrame(files, columns=["filename"])
path_names = path + "/" + dataframe.filename.values
dataframe = dataframe.filename.str.rsplit("_", n=4, expand=True)
len(files)
# Out:
# 668

# %%
def visualise_breast_tissue(patient_id):
    pass

# %%
example = "12242"

example_df = get_patient_dataframe(example)
max_point = [example_df.y.max()-1, example_df.x.max()-1]
grid = 255*np.ones(shape = (max_point[0] + 50, max_point[1] + 50, 3)).astype(np.uint8)
mask = 255*np.ones(shape = (max_point[0] + 50, max_point[1] + 50, 3)).astype(np.uint8)

broken_patches = []
for n in range(len(example_df)):
    try:
        image = imread(example_df.path.values[n])

        x_start = example_df.x.values[n] - 1
        y_start = example_df.y.values[n] - 1
        x_end = x_start + 50
        y_end = y_start + 50

        grid[y_start:y_end, x_start:x_end] = image
     
        #mask[y_start:y_end, x_start:x_end] = np.ones(shape=(50,50,3))
    except ValueError:
        broken_patches.append(example_df.path.values[n])

# %%
min_point = [example_df.y.min(), example_df.x.min()]
min_point
# Out:
# [1, 51]

# %% [markdown]
# Save image coordinates

# %%
example_df.head()

example_df.to_pickle("patient12242_coordinate.pkl")

# %%
from pandas import api 
from pandas.api import types 
from pandas.api.types import is_numeric_dtype

# %%
is_numeric_dtype(example_df['target'])
data = example_df[['x','y', 'target']] 
data.head()
# Out:
#       x    y  target
# 0  1001  251       0
# 1  1001  301       0
# 2  1001  451       0
# 3  1001  401       0
# 4  1001  351       0

# %%
import numpy as np

import matplotlib.pyplot as plt
from  matplotlib.pyplot import scatter

x=example_df['x']
y=example_df['y']
data = example_df[['x','y', 'target']]
colors = ("grey", "red")
groups = ("0","1")

# Create plot
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x,y, alpha=0.8, edgecolor='none', s=30, c=data.target )
#for data, color, group in zip(data, colors, groups):
# x,y=data
#  ax.scatter(x, y, alpha=0.8, c=colors, edgecolor='none', s=30, label=group)

plt.title('patient 12242')
plt.legend(labels=groups)
plt.legend(loc=2)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(20,20))
plt.imshow(grid, cmap="Blues", vmin=150, alpha=0.8)
plt.grid(False)

# %% [markdown]
# create labels for precition

# %%
#create labels
ImagePatch = glob('/content/drive/My Drive/IDC/12242/**/*.png', recursive=True) #replace 'D:/comp5703/input with own input patch
Pattern0 = '*class0.png'
Pattern1 = '*class1.png'
Class0 = fnmatch.filter(ImagePatch, Pattern0)
Class1 = fnmatch.filter(ImagePatch, Pattern1)

def image_proc(lindex,uindex):
    x = []
    y = []

    for img in ImagePatch[lindex:uindex]:
        full_size_image = cv2.imread(img)
        x.append(cv2.resize(full_size_image, (50,50), interpolation=cv2.INTER_CUBIC))
        if img in Class0:
            y.append(0)
        elif img in Class1:
            y.append(1)
        else:
            return
    return x,y

X,Y = image_proc(0,2000)

# %%
#data description
original_data = pd.DataFrame()
original_data["image"]=X
original_data["label"]=Y
X1=original_data["image"]
Y1=original_data["label"]

def describe_data(x,y):
    print('Total number: {}'.format(len(x)))
    print('Number of IDC(-): {}'.format(np.sum(y==0)))
    print('Number of IDC(+): {}'.format(np.sum(y==1)))
    print('Percentage of IDC(+) : {:.2f}%'.format(100*np.mean(y)))
describe_data(X1, Y1)
# Out:
# Total number: 1097
# Number of IDC(-): 668
# Number of IDC(+): 429
# Percentage of IDC(+) : 39.11%

# %%
np.save("X_patient12242.npy",X)

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive'
