# %%
 # Use GPU
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 132684 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.13-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.13-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.13-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse -o nonempty drive

# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
os.chdir('/content/drive/My Drive')
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %%
#import library
import pandas as pd
import numpy as np
from glob import glob
import fnmatch
import cv2

# %%
X1=np.load('X_new.npy')
Y1=np.load('Y_new.npy')

# %%
X=X1[0:40000]
Y=Y1[0:40000]

# %%
import matplotlib.pylab as plt
import itertools
import sklearn
from sklearn import model_selection
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, learning_curve, GridSearchCV
itertools
import keras
from keras import backend, Model
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential, model_from_json
from keras.optimizers import SGD, RMSprop, Adam, Adagrad, Adadelta
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPool2D, MaxPooling2D, GlobalAveragePooling2D, ZeroPadding2D, Input, concatenate, Add, AveragePooling2D, LeakyReLU
from keras.initializers import glorot_uniform
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
x_sub = np.array(X)
x_sub=x_sub/255.0
x_sub_shape = x_sub.shape[1] * x_sub.shape[2] * x_sub.shape[3]
x_flat = x_sub.reshape(x_sub.shape[0], x_sub_shape)

# %%
r = pd.value_counts(Y)
print(r)
from imblearn.under_sampling import RandomUnderSampler
rus=RandomUnderSampler(ratio='auto')
x_flat_resample,y_sub_resample=rus.fit_sample(x_flat,Y)
len(x_flat_resample)
r = pd.value_counts(y_sub_resample)
print(r)
# Out:
# 0    30556
# 1     9444
# dtype: int64
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# 1    9444
# 0    9444
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_flat_resample, y_sub_resample, test_size=0.2, random_state = 2) # 0.2 test_size means 20%

# %%
from keras.utils.np_utils import to_categorical
Y_train_c = to_categorical(y_train, num_classes = 2)
Y_test_c = to_categorical(y_test, num_classes = 2)

# %%
for i in range(len(X_train)):
    height, width, channels = 50,50,3
    X_train_reshape = X_train.reshape(len(X_train),height,width,channels)

for i in range(len(X_test)):
    height, width, channels = 50,50,3
    X_test_reshape = X_test.reshape(len(X_test),height,width,channels)
dfRos = pd.DataFrame()
dfRos["labels"]=y_train
labRos = dfRos['labels']

# %%
r = pd.value_counts(y_train)
print(r)
# Out:
# 0    7569
# 1    7541
# dtype: int64

# %%
print(X_train_reshape.shape)
print(Y_train_c.shape)
print(X_test_reshape.shape)
print(Y_test_c.shape)
# Out:
# (15110, 50, 50, 3)
# (15110, 2)
# (3778, 50, 50, 3)
# (3778, 2)

# %%
inp=Input(shape=(50, 50, 3))

def identity_block(X, f, filters, stage, block):
 
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
 
    F1, F2, F3 = filters
 
    X_shortcut = X
 
    X = Conv2D(filters = F1, kernel_size = (1,1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
 
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
 
    X = Conv2D(filters = F3, kernel_size = (1,1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)
 
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
 
    return X

def convolution_block(X, f, filters, stage, block, s=2):
 
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    F1, F2, F3 = filters
 
    X_shortcut = X
 
    X = Conv2D(filters = F1, kernel_size = (1,1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
 
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
 
    X = Conv2D(filters = F3, kernel_size = (1,1), strides = (1,1), name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed = 0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)
 
    X_shortcut = Conv2D(F3, (1,1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name=bn_name_base + '1')(X_shortcut)
 
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
 
    return X

X = ZeroPadding2D((3, 3))(inp)
 
X = Conv2D(64, (7, 7), strides = (2,2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3, 3), strides = (2,2))(X)
 
X = convolution_block(X, f = 3, filters = [64,64,256], stage = 2, block = 'a', s = 1)
X = identity_block(X, 3, [64,64,256], stage=2, block='b')
X = identity_block(X, 3, [64,64,256], stage=2, block='c')
 
X = convolution_block(X, f = 3, filters = [128,128,512], stage = 3, block = 'a', s = 2)
X = identity_block(X, 3, [128,128,512], stage=3, block='b')
X = identity_block(X, 3, [128,128,512], stage=3, block='c')
X = identity_block(X, 3, [128,128,512], stage=3, block='d')
 
X = convolution_block(X, f = 3, filters = [256,256,1024], stage = 4, block = 'a', s = 2)
X = identity_block(X, 3, [256,256,1024], stage=4, block='b')
X = identity_block(X, 3, [256,256,1024], stage=4, block='c')
X = identity_block(X, 3, [256,256,1024], stage=4, block='d')    
X = identity_block(X, 3, [256,256,1024], stage=4, block='e')
X = identity_block(X, 3, [256,256,1024], stage=4, block='f')
 
X = convolution_block(X, f = 3, filters = [512,512,2048], stage = 5, block = 'a', s = 2)
X = identity_block(X, 3, [512,512,2048], stage=5, block='b')
X = identity_block(X, 3, [512,512,2048], stage=5, block='c')
 
X = AveragePooling2D((2, 2), name='avg_pool')(X)
 
X = Flatten()(X)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.

# %%
Y = Conv2D(32,(3, 3), activation='relu',padding = 'Same',strides= 2)(inp)
Y = Conv2D(32,(3, 3), padding = 'Same',activation='relu')(Y)
Y = Conv2D(32,(3, 3), padding = 'Same',activation='relu')(Y)
Y = MaxPooling2D(2, 2)(Y)
Y = Dropout(0.25)(Y)
Y = Flatten()(Y)
Y = Dense(32, activation='relu')(Y)
Y = Dropout(0.25)(Y)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
def DenseLayer(Z, nb_filter, bn_size=4, alpha=0.0, drop_rate=0.2):
    
    # Bottleneck layers
    Z = BatchNormalization(axis=3)(Z)
    Z = LeakyReLU(alpha=alpha)(Z)
    Z = Conv2D(bn_size*nb_filter, (1, 1), strides=(1,1), padding='same')(Z)
    
    # Composite function
    Z = BatchNormalization(axis=3)(Z)
    Z = LeakyReLU(alpha=alpha)(Z)
    Z = Conv2D(nb_filter, (3, 3), strides=(1,1), padding='same')(Z)
    
    if drop_rate: Z = Dropout(drop_rate)(Z)
    
    return Z


def DenseBlock(Z, nb_layers, growth_rate, drop_rate=0.2):
    
    for ii in range(nb_layers):
        conv = DenseLayer(Z, nb_filter=growth_rate, drop_rate=drop_rate)
        Z = concatenate([Z, conv], axis=3)
        
    return Z


def TransitionLayer(Z, compression=0.5, alpha=0.0, is_max=0):
    
    nb_filter = int(Z.shape.as_list()[-1]*compression)
    Z = BatchNormalization(axis=3)(Z)
    Z = LeakyReLU(alpha=alpha)(Z)
    Z = Conv2D(nb_filter, (1, 1), strides=(1,1), padding='same')(Z)
    if is_max != 0: Z = MaxPooling2D(pool_size=(2, 2), strides=2)(Z)
    else: Z = AveragePooling2D(pool_size=(2, 2), strides=2)(Z)
    
    return Z

growth_rate = 12
Z = Conv2D(growth_rate*2, (3, 3), strides=1, padding='same')(inp)
Z = BatchNormalization(axis=3)(Z)
Z = LeakyReLU(alpha=0.1)(Z)
 
Z = DenseBlock(Z, 12, growth_rate, drop_rate=0.2)
 
Z = TransitionLayer(Z)
 
Z = DenseBlock(Z, 12, growth_rate, drop_rate=0.2)
 
Z = TransitionLayer(Z)
 
Z = DenseBlock(Z, 12, growth_rate, drop_rate=0.2)
 
Z = BatchNormalization(axis=3)(Z)
Z = GlobalAveragePooling2D()(Z)

# %%
merger=concatenate([X,Y,Z])

# %%
op=Dense(2, activation='softmax')(merger)

# %%
model=Model(inputs=inp, outputs=op)

# %%
datagen = ImageDataGenerator(
        rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True)

# %%
sgd=SGD(lr=0.001, nesterov=True, decay=1e-6, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 50, 50, 3)    0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 50, 50, 24)   672         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 50, 24)   96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 50, 50, 24)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50, 24)   96          leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 50, 50, 24)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 50, 50, 48)   1200        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 50, 50, 48)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 50, 50, 48)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 12)   5196        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 50, 50, 12)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 50, 50, 36)   0           leaky_re_lu_1[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 50, 50, 36)   144         concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 50, 50, 36)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 48)   1776        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 50, 50, 48)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 50, 50, 48)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 12)   5196        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 50, 50, 12)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 50, 50, 48)   0           concatenate_1[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 48)   192         concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 50, 50, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 48)   2352        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 48)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 50, 50, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 50, 50, 12)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 60)   0           concatenate_2[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 60)   240         concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 50, 50, 60)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 50, 50, 48)   2928        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 48)   192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 50, 50, 48)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 50, 50, 12)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 50, 50, 72)   0           concatenate_3[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 72)   288         concatenate_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 50, 50, 72)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 50, 50, 48)   3504        leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 50, 50, 48)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 50, 50, 12)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 50, 50, 84)   0           concatenate_4[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 50, 50, 84)   336         concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 50, 50, 84)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 50, 50, 48)   4080        leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 50, 50, 48)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 50, 50, 12)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 50, 50, 96)   0           concatenate_5[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 50, 50, 96)   384         concatenate_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 50, 50, 96)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 48)   4656        leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 50, 50, 48)   192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 50, 50, 12)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 50, 50, 108)  0           concatenate_6[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 50, 50, 108)  432         concatenate_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 50, 50, 108)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 50, 50, 48)   5232        leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 48)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 50, 50, 12)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 50, 50, 120)  0           concatenate_7[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 120)  480         concatenate_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 50, 50, 120)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 50, 50, 48)   5808        leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 50, 50, 48)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 50, 50, 12)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 50, 50, 132)  0           concatenate_8[0][0]
#                                                                  dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 50, 50, 132)  528         concatenate_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 50, 50, 132)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 50, 50, 48)   6384        leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 50, 50, 48)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 50, 50, 12)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 50, 50, 144)  0           concatenate_9[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 50, 50, 144)  576         concatenate_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 50, 50, 144)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 50, 50, 48)   6960        leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 50, 50, 48)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 50, 50, 12)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 50, 50, 156)  0           concatenate_10[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 50, 50, 156)  624         concatenate_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 50, 50, 156)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 50, 50, 48)   7536        leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 50, 50, 48)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 50, 50, 48)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 50, 50, 12)   5196        leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 50, 50, 12)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None,
aky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 12, 12, 12)   0           conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 12, 12, 222)  0           concatenate_32[0][0]
#                                                                  dropout_35[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 2, 2, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 12, 12, 222)  888         concatenate_33[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 2, 2, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, 12, 12, 222)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 2, 2, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 12, 12, 48)   10704       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 2, 2, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 12, 12, 48)   192         conv2d_73[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, 12, 12, 48)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 12, 12, 12)   5196        leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 12, 12, 12)   0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 12, 12, 234)  0           concatenate_33[0][0]
#                                                                  dropout_36[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 12, 12, 234)  936         concatenate_34[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, 12, 12, 234)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 12, 12, 48)   11280       leaky_re_lu_72[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 12, 12, 48)   192         conv2d_75[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 2, 2, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)      (None, 12, 12, 48)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 2, 2, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 12, 12, 12)   5196        leaky_re_lu_73[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 12, 12, 12)   0           conv2d_76[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 12, 12, 246)  0           concatenate_34[0][0]
#                                                                  dropout_37[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 12, 12, 246)  984         concatenate_35[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)      (None, 12, 12, 246)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 25, 25, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 12, 12, 48)   11856       leaky_re_lu_74[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 25, 25, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 12, 12, 48)   192         conv2d_77[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_75 (LeakyReLU)      (None, 12, 12, 48)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 12, 12, 12)   5196        leaky_re_lu_75[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 2, 2, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 12, 12, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 12, 12, 12)   0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 2, 2, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 4608)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 12, 12, 258)  0           concatenate_35[0][0]
#                                                                  dropout_38[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           147488      flatten_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 12, 12, 258)  1032        concatenate_36[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 258)          0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 2338)         0           flatten_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            4678        concatenate_37[0][0]
# ==================================================================================================
# Total params: 24,260,732
# Trainable params: 24,192,720
# Non-trainable params: 68,012
# __________________________________________________________________________________________________

# %%
class MetricsCheckpoint(Callback):
    def __init__(self, savepath):
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)
        
def plot_cm(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.figure(figsize = (5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 verticalalignment = "center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
def plot_lc(history):
    plt.figure(figsize=(8,8))
    plt.subplot(1,2,1)
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.savefig('./accuracy_curve.png')
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')

# %%
X_train_reshape_train,X_train_valid,Y_train_train,Y_train_valid = train_test_split(X_train_reshape,Y_train_c,test_size = 0.2, random_state = 0)

# %%
history = model.fit_generator(datagen.flow(X_train_reshape_train,Y_train_train, batch_size=32),validation_data=(X_train_valid,Y_train_valid),
                        steps_per_epoch=len(X_train_reshape_train) / 32, epochs=80 ,callbacks = [MetricsCheckpoint('logs')],verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/80
# 378/377 [==============================] - 294s 778ms/step - loss: 0.5605 - acc: 0.7638 - val_loss: 2.8326 - val_acc: 0.6052
# Epoch 2/80
# 378/377 [==============================] - 244s 647ms/step - loss: 0.4836 - acc: 0.7989 - val_loss: 1.3704 - val_acc: 0.5132
# Epoch 3/80
# 378/377 [==============================] - 244s 646ms/step - loss: 0.4571 - acc: 0.8105 - val_loss: 0.4802 - val_acc: 0.7657
# Epoch 4/80
# 378/377 [==============================] - 244s 647ms/step - loss: 0.4551 - acc: 0.8103 - val_loss: 0.9569 - val_acc: 0.6929
# Epoch 5/80
# 378/377 [==============================] - 245s 647ms/step - loss: 0.4245 - acc: 0.8268 - val_loss: 0.8393 - val_acc: 0.6889
# Epoch 6/80
# 378/377 [==============================] - 245s 648ms/step - loss: 0.4197 - acc: 0.8305 - val_loss: 1.3668 - val_acc: 0.5516
# Epoch 7/80
# 378/377 [==============================] - 245s 649ms/step - loss: 0.4137 - acc: 0.8278 - val_loss: 1.2454 - val_acc: 0.6264
80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2891 - acc: 0.8801 - val_loss: 0.5032 - val_acc: 0.7770
# Epoch 65/80
# 378/377 [==============================] - 243s 643ms/step - loss: 0.2943 - acc: 0.8796 - val_loss: 0.5185 - val_acc: 0.8339
# Epoch 66/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2886 - acc: 0.8821 - val_loss: 0.7099 - val_acc: 0.7740
# Epoch 67/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2881 - acc: 0.8810 - val_loss: 0.8485 - val_acc: 0.6823
# Epoch 68/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2891 - acc: 0.8801 - val_loss: 0.8491 - val_acc: 0.7601
# Epoch 69/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2891 - acc: 0.8800 - val_loss: 0.8941 - val_acc: 0.6721
# Epoch 70/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2931 - acc: 0.8806 - val_loss: 0.6432 - val_acc: 0.7594
# Epoch 71/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2912 - acc: 0.8800 - val_loss: 2.4954 - val_acc: 0.5007
# Epoch 72/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2810 - acc: 0.8836 - val_loss: 1.0657 - val_acc: 0.6205
# Epoch 73/80
# 378/377 [==============================] - 243s 642ms/step - loss: 0.2818 - acc: 0.8849 - val_loss: 0.4448 - val_acc: 0.8068
# Epoch 74/80
# 378/377 [==============================] - 243s 642ms/step - loss: 0.2798 - acc: 0.8856 - val_loss: 0.5108 - val_acc: 0.7925
# Epoch 75/80
# 378/377 [==============================] - 243s 643ms/step - loss: 0.2871 - acc: 0.8843 - val_loss: 0.6264 - val_acc: 0.7412
# Epoch 76/80
# 378/377 [==============================] - 243s 642ms/step - loss: 0.2871 - acc: 0.8815 - val_loss: 1.4651 - val_acc: 0.6085
# Epoch 77/80
# 378/377 [==============================] - 243s 642ms/step - loss: 0.2803 - acc: 0.8838 - val_loss: 0.7765 - val_acc: 0.6850
# Epoch 78/80
# 378/377 [==============================] - 242s 640ms/step - loss: 0.2821 - acc: 0.8840 - val_loss: 1.0826 - val_acc: 0.6555
# Epoch 79/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2819 - acc: 0.8857 - val_loss: 0.3741 - val_acc: 0.8395
# Epoch 80/80
# 378/377 [==============================] - 242s 641ms/step - loss: 0.2805 - acc: 0.8862 - val_loss: 0.3732 - val_acc: 0.8415

# %%
score = model.evaluate(X_test_reshape,Y_test_c)
print(score)
# Out:
# 3778/3778 [==============================] - 19s 5ms/step
# [0.3844418399368229, 0.838009528851244]

# %%
from sklearn.metrics import confusion_matrix, make_scorer, accuracy_score
y_pred = model.predict(X_test_reshape)
Y_pred_classes = np.argmax(y_pred,axis=1) 
Y_true = np.argmax(Y_test_c,axis=1)
dict_characters = {0: 'IDC(-)', 1: 'IDC(+)'}
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
plot_cm(confusion_mtx, classes = list(dict_characters.values())) 
plt.show()
plot_lc(history)
plt.show()

# %%
print(confusion_matrix(Y_true, Y_pred_classes))
from sklearn import metrics
print(metrics.classification_report(Y_true, Y_pred_classes))
# Out:
# [[1626  249]
#  [ 363 1540]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84      1875
#            1       0.86      0.81      0.83      1903
#
#     accuracy                           0.84      3778
#    macro avg       0.84      0.84      0.84      3778
# weighted avg       0.84      0.84      0.84      3778

# %%
cm= confusion_matrix(Y_true, Y_pred_classes)
sensitivity= cm[1,1]/(cm[1,1]+cm[1,0])
print('Sensitivity : ', sensitivity )
secificity= cm[0,0]/(cm[0,0]+cm[0,1])
print('Specificity : ',secificity)
# Out:
# Sensitivity :  0.8092485549132948
# Specificity :  0.8672

# %%
from sklearn.metrics import auc,roc_curve
#  ROC curve
fpr, tpr, thresholds = roc_curve(Y_true, y_pred[:,1], pos_label=1)
#  ROC area
pred_score = auc(fpr, tpr)
print(f'Area Under Curve is {pred_score}')
# Out:
# Area Under Curve is 0.922701979330881

# %%
plt.figure()
plt.plot(fpr, tpr, color='orange', label='ROC curve (area = %0.2f)' % pred_score)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([-0.01, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve of Stacking Model')
plt.legend(loc="lower right")

# %%
pred = model.predict(X_test_reshape)
pred_x = []
for i in range(len(pred)):
  if pred[i,1]>0.5:
    pred_x.append(1)
  else:
    pred_x.append(0)

a = []
b = 0
for i in range(len(pred)):
  if pred_x[i] == Y_test_c[i,1]:
    a.append('yes')
    b=b+1
  else:
    a.append('no')
type(a)
df = pd.DataFrame(a, columns=['Stacking'])
print(df)
df.to_csv('yes-no-stacking.csv', index=False, header=True)
# Out:
#      Stacking
# 0          no
# 1         yes
# 2         yes
# 3          no
# 4         yes
# ...       ...
# 3773      yes
# 3774      yes
# 3775      yes
# 3776      yes
# 3777      yes
#
# [3778 rows x 1 columns]

# %%
X_12242=np.load('./X_patient12242.npy')
X_12242=X_12242/255
y_pred_12242 = model.predict(X_12242)

# %%
y_pred_12242 = model.predict(X_12242)
np.save('./y_pred_12242_stack.npy',y_pred_12242)

# %%
y_pred_12242=np.load('y_pred_12242_stack.npy')

# %%
print(y_pred_12242[0:100])
# Out:
# [[9.89902377e-01 1.00976527e-02]
#  [9.78159606e-01 2.18403861e-02]
#  [9.57960069e-01 4.20399345e-02]
#  [9.92580116e-01 7.41986185e-03]
#  [9.89168167e-01 1.08318767e-02]
#  [9.02059853e-01 9.79401916e-02]
#  [6.03376150e-01 3.96623820e-01]
#  [9.73655641e-01 2.63443533e-02]
#  [9.92559314e-01 7.44070578e-03]
#  [9.96104240e-01 3.89574748e-03]
#  [9.89405453e-01 1.05945440e-02]
#  [9.77975547e-01 2.20243856e-02]
#  [8.40982854e-01 1.59017131e-01]
#  [9.10732210e-01 8.92677605e-02]
#  [9.91675377e-01 8.32454395e-03]
#  [9.77520645e-01 2.24793665e-02]
#  [8.59539509e-01 1.40460491e-01]
#  [8.43199253e-01 1.56800821e-01]
#  [9.86198545e-01 1.38014108e-02]
#  [9.20551538e-01 7.94484913e-02]
#  [9.63307858e-01 3.66921946e-02]
#  [9.91299570e-01 8.70047137e-03]
#  [9.52249646e-01 4.77503985e-02]
#  [9.04352844e-01 9.56471339e-02]
#  [8.97999525e-01 1.02000453e-01]
#  [9.01235461e-01 9.87644866e-02]
#  [9.36092854e-01 6.39071167e-02]
#  [7.45938480e-01 2.54061460e-01]
#  [9.46847439e-01 5.31525426e-02]
#  [9.73816454e-01 2.61835549e-02]
#  [8.15789521e-01 1.84210420e-01]
#  [5.91085196e-01 4.08914804e-01]
#  [9.93307590e-01 6.69243280e-03]
#  [9.40337956e-01 5.96620813e-02]
#  [9.60943162e-01 3.90568376e-02]
#  [6.53169692e-01 3.46830308e-01]
#  [9.79056358e-01 2.09436193e-02]
#  [9.07101095e-01 9.28988382e-02]
#  [9.25336242e-01 7.46637955e-02]
#  [9.08694804e-01 9.13052261e-02]
#  [8.10022533e-01 1.89977482e-01]
#  [7.32116222e-01 2.67883748e-01]
#  [9.70022380e-01 2.99776588e-02]
#  [9.12114441e-01 8.78855512e-02]
#  [9.28056419e-01 7.19436109e-02]
#  [9.71766472e-01 2.82335114e-02]
#  [8.29592168e-01 1.70407787e-01]
#  [6.59393013e-01 3.40606958e-01]
#  [8.65397871e-01 1.34602159e-01]
#  [9.40725982e-01 5.92739955e-02]
#  [8.05945873e-01 1.94054097e-01]
#  [9.82260764e-01 1.77392662e-02]
#  [8.97779763e-01 1.02220260e-01]
#  [7.03107357e-01 2.96892673e-01]
#  [9.80578721e-01 1.94213018e-02]
#  [8.90295982e-01 1.09703995e-01]
#  [3.83609504e-01 6.16390467e-01]
#  [5.86914718e-01 4.13085222e-01]
#  [3.58920842e-01 6.41079187e-01]
#  [7.73922801e-01 2.26077199e-01]
#  [2.72055030e-01 7.27944970e-01]
#  [6.72207952e-01 3.27792019e-01]
#  [9.52811658e-01 4.71883602e-02]
#  [8.23071659e-01 1.76928371e-01]
#  [9.87875700e-01 1.21242171e-02]
#  [9.04818177e-01 9.51818004e-02]
#  [5.69236398e-01 4.30763572e-01]
#  [9.29753065e-01 7.02469423e-02]
#  [3.28443021e-01 6.71556950e-01]
#  [4.49832708e-01 5.50167263e-01]
#  [9.08278704e-01 9.17213038e-02]
#  [9.47392702e-01 5.26073538e-02]
#  [8.23097110e-01 1.76902875e-01]
#  [9.37462449e-01 6.25375584e-02]
#  [8.54584038e-01 1.45416006e-01]
#  [9.51744318e-01 4.82556820e-02]
#  [5.92042267e-01 4.07957673e-01]
#  [4.87927616e-01 5.12072384e-01]
#  [5.96211791e-01 4.03788179e-01]
#  [6.05045617e-01 3.94954354e-01]
#  [8.96347344e-01 1.03652641e-01]
#  [9.28565741e-01 7.14342892e-02]
#  [8.14340889e-01 1.85659125e-01]
#  [5.43914378e-01 4.56085622e-01]
#  [9.25869584e-01 7.41304755e-02]
#  [9.03866231e-01 9.61337984e-02]
#  [3.91693592e-01 6.08306468e-01]
#  [8.34269345e-01 1.65730730e-01]
#  [7.21463203e-01 2.78536767e-01]
#  [8.39090526e-01 1.60909444e-01]
#  [9.99109328e-01 8.90637340e-04]
#  [5.42793155e-01 4.57206815e-01]
#  [9.48177397e-01 5.18226437e-02]
#  [3.86188656e-01 6.13811314e-01]
#  [9.90880489e-01 9.11956001e-03]
#  [9.55023587e-01 4.49764580e-02]
#  [9.98472273e-01 1.52767985e-03]
#  [2.00091183e-01 7.99908817e-01]
#  [7.81196415e-01 2.18803629e-01]
#  [8.78777862e-01 1.21222176e-01]]

# %%
label=[]
i=0
for line in y_pred_12242:
  if line[0]>=0.5:
    label.append(0)
  else:
    label.append(1)
  i=i+1

# %%
y_pred_12242_new=np.c_[y_pred_12242,label]
example_df=pd.read_pickle("patient12242_coordinate.pkl")
example_df['target_new']=y_pred_12242_new[:,2].tolist()
example_df["target_new"]=example_df['target_new'].astype(int)
example_df
# Out:
#         x    y  ...                                               path target_new
# 0    1001  251  ...  /content/drive/My Drive/IDC/12242/0/12242_idx5...          0
# 1    1001  301  ...  /content/drive/My Drive/IDC/12242/0/12242_idx5...          0
# 2    1001  451  ...  /content/drive/My Drive/IDC/12242/0/12242_idx5...          0
# 3    1001  401  ...  /content/drive/My Drive/IDC/12242/0/12242_idx5...          0
# 4    1001  351  ...  /content/drive/My Drive/IDC/12242/0/12242_idx5...          0
# ..    ...  ...  ...                                                ...        ...
# 424  2501  951  ...  /content/drive/My Drive/IDC/12242/1/12242_idx5...          0
# 425  2451  851  ...  /content/drive/My Drive/IDC/12242/1/12242_idx5...          1
# 426  2451  951  ...  /content/drive/My Drive/IDC/12242/1/12242_idx5...          1
# 427  2451  901  ...  /content/drive/My Drive/IDC/12242/1/12242_idx5...          1
# 428  2501  901  ...  /content/drive/My Drive/IDC/12242/1/12242_idx5...          1
#
# [1097 rows x 5 columns]

# %%
from pandas import api 
from pandas.api import types 
from pandas.api.types import is_numeric_dtype
import matplotlib.pyplot as plt
from  matplotlib.pyplot import scatter
x=example_df['x']
y=example_df['y']
data = example_df[['x','y', 'target_new']]
colors = ("grey", "red")
groups = ("0","1")
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x,y, alpha=0.8, edgecolor='none', s=30, c=data.target_new )
plt.title('patient 12242 _predicted')
plt.show()

# %%
X_10253=np.load('./X_patient10253_CNN.npy')
XX_10253 = X_10253/255

y_pred_10253=model.predict(XX_10253)
np.save('./y_pred_10253_cnn.npy',y_pred_10253)

y_pred_10253=np.load('y_pred_10253_cnn.npy')

# %%
print(y_pred_10253[0:10])
# Out:
# [[9.9994099e-01 5.9016940e-05]
#  [9.9981862e-01 1.8142675e-04]
#  [9.9195910e-01 8.0409776e-03]
#  [9.9987805e-01 1.2197706e-04]
#  [9.9990129e-01 9.8643373e-05]
#  [9.9714774e-01 2.8522781e-03]
#  [9.9996567e-01 3.4283621e-05]
#  [9.9984968e-01 1.5026591e-04]
#  [9.9994910e-01 5.0845734e-05]
#  [9.9993825e-01 6.1788327e-05]]

# %%
label=[]
i=0
for line in y_pred_10253:
  if line[0]>=0.5:
    label.append(0)
  else:
    label.append(1)
  i=i+1

y_pred_10253_new=np.c_[y_pred_10253,label]

example_df=pd.read_pickle("patient10253_coordinate.pkl")
example_df['target_new']=y_pred_10253_new[:,2].tolist()

example_df["target_new"]=example_df['target_new'].astype(int)
example_df
# Out:
#        x     y  ...                                               path target_new
# 0   1001  1001  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 1   1001  1151  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 2   1001  1551  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 3   1001  1201  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 4   1001  1301  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# ..   ...   ...  ...                                                ...        ...
# 65   851   501  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 66   851   751  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 67   851   551  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 68   851   651  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
# 69   901   351  ...  /content/drive/My Drive/IDC_regular_ps50_idx5/...          0
#
# [549 rows x 5 columns]

# %%
x=example_df['x']
y=example_df['y']
data = example_df[['x','y', 'target_new']]
colors = ("grey", "red")
groups = ("0","1")
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(x,y, alpha=0.8, edgecolor='none', s=30, c=data.target_new )
plt.title('patient 10253 _predicted')
plt.show()

# %%
from sklearn.externals import joblib
joblib.dump(model, "train_model_stack_80.m")
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['train_model_stack_80.m']
